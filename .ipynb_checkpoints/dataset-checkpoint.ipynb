# %%
# !pip3 install wordcloud

# %%
import re
import nltk
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk import pos_tag, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

import gensim
from gensim import corpora
from gensim import similarities
from gensim import models

from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## EDA

# %%
# Open the text file
with open("text_converter/justice.txt", "r") as file:
    # Read the entire contents of the file into a string
    text = file.read()

# Split the text into sentences using the nltk sentence tokenizer
sentences = nltk.sent_tokenize(text)
print(len(sentences))
print(sentences[:20])

corpus = PlaintextCorpusReader('text_converter', '.+\.txt')
#doc = [corpus.words(f) for f in corpus.fileids()] #Take all files
doc = corpus.words('justice.txt')
print(len(doc))
# Out:
# 5135
# ["JUSTICE \n\n\nWHAT'S THE RIGHT \nTHING TO DO?", 'MICHAEL J. SANDEL \n\n\n\nLiberalism and the Limits ofJustice( 1982; 2nd ed., 1998) \n\nLiberalism and Its Critics, editor (1984) \n\nDemocracy’s Discontent: America in Search of a Public Philosophy (1996) \nPublic Philosophy: Essays on Morality in Politics (2005) \n\nThe Case Against Perfection: Ethics in the Age of Genetic Engineering (2007) \n\nJustice: A Reader, editor (2007) \n\n\n\n\nJUSTICE \n\n\nWHAT’S \n\nTHE \n\nRIGHT THING \nTO DO?', 'MICHAEL J. SANDEL \n\n\nFARRAR, STRAUS AND GIROUX \nNEW YORK \n\n\nFor Kiku, with love \n\n\n\n\nCONTENTS \n\n\nDEDICATION \n\n1.', 'DOING THE RIGHT THING \n\n2.', 'THE GREATEST HAPPINESS PRINCIPLE / UTILITARIANISM \n\n3.', 'DO WE OWN OURSELVES?', '/ LIBERTARIANISM \n\n4.', 'HIRED HELP / MARKETS AND MORALS \n\n5.', 'WHAT MATTERS IS THE MOTIVE / IMMANUEL KANT \n\n6.', 'THE CASE FOR EQUALITY / JOHN RAWLS \n\n7.', 'ARGUING AFFIRMATIVE ACTION \n\n8. WHO DESERVES WHAT?', '/ ARISTOTLE \n\n9.', 'WHAT DO WE OWE ONE ANOTHER?', '/ DILEMMAS OF LOYALTY \n\n10.', 'JUSTICE AND THE COMMON GOOD \n\n\nNOTES \n\nACKNOWLEDGMENTS \n\nINDEX \n\n\n\n1.', 'DOING THE RIGHT THING \n\n\nIn the summer of 2004, Hurricane Charley roared out of the Gulf of Mexico and swept across Florida \n\nto the Atlantic Ocean.', 'The storm claimed twenty-two lives and caused $11 billion in damage.', '- It also left \nin its wake a debate about price gouging.', 'At a gas station in Orlando, they were selling two-dollar bags of ice for ten dollars.', 'Lacking power for \nrefrigerators or air-conditioning in the middle of August, many people had little choice but to pay up.']
# 116500

# %%
fdist_doc = FreqDist(doc).most_common(50)
# print(fdist_justice.most_common(20))
x, y = zip(*fdist_doc)
plt.figure(figsize=(50,30))
plt.margins(0.02)
plt.bar(x, y)
plt.xlabel('Words', fontsize=50)
plt.ylabel('Frequency of Words', fontsize=50)
plt.yticks(fontsize=40)
plt.xticks(rotation=60, fontsize=40)
plt.title('Frequency of 50 Most Common Words', fontsize=60)
plt.show()

# %%
# Initialize variables to store the average sentence length, minimum and maximum sentence lengths
average_sentence_length = 0
min_sentence_length = float("inf")
max_sentence_length = float("-inf")
min_sen = ""
max_sen = ""

# Loop through each sentence
for sentence in sentences:
    # Tokenize the sentence into words
    words = nltk.word_tokenize(sentence)
    # Calculate the length of the sentence
    sentence_length = len(words)
    # Update the average sentence length
    average_sentence_length += sentence_length
    # Update the minimum sentence length if necessary
    # min_sentence_length = min(min_sentence_length, sentence_length)
    if sentence_length < min_sentence_length:
        min_sentence_length = sentence_length
        min_sen = sentence
    # Update the maximum sentence length if necessary
    #max_sentence_length = max(max_sentence_length, sentence_length)
    if sentence_length > max_sentence_length:
        max_sentence_length = sentence_length
        max_sen = sentence


# Calculate the average sentence length
average_sentence_length = average_sentence_length / len(justice_lemmed)

# Print the results
print("Average sentence length:", average_sentence_length)
print("Minimum sentence length:", min_sentence_length)
print(min_sen)
print("Maximum sentence length:", max_sentence_length)
print(max_sen)
# Out:
# Average sentence length: 21.319970304380103
# Minimum sentence length: 1
# .
# Maximum sentence length: 2871
# Please use the search function on your eReading device to search for terms of interest For your
# reference, the terms that appear in the print index are listed below
#
# Abe, Shinzo
# abortion debate
# Abu Ghraib prison
# Adenauer, Konrad
# affirmative action
# arguments about purpose
# compensatory argument
# correcting for testing gap
# diversity argument
# Hopwood case
# question of
#
# higher education purpose
#
# reasons for taking race and ethnicity
#
# into account
#
# for white
#
# people
#
# Afghan goatherds
# After Virtue (MacIntyre)
#
# agent standpoint, comparison with object standpoint
# air pollution standards, cost-benefit analysis
# Allen, Woody
# Amazon.com
#
# American International Group (AIG)
#
# Arne ri Corps
# Anderson, Elizabeth
# anti-Jewish quotas
#
# apologies, public, for historic injustices: argument against
#
# and moral individualism
#
# obligations of solidarity
#
# question of collective responsibility
#
# World War II wrongs
#
# Aristotle
#
# defense of slavery
#
# and surrogacy debate
#
# theory of justice
#
# theory of the good
#
# views on distributive justice
#
# views on good life
#
# views on learning by doing
#
# views on politics
#
# views on virtue
#
# Arthur, Chester A.
#
# assisted suicide
#
# auctioning college admissions
#
# Australia, question of historic injustices to indigenous peoples
# autonomy: comparison with heteronomy
#
#
# as ideal behind moral force in contracts
# Kant’s view
#
# and question of prostitution
# relationship to duty
# relationship to morality
# and same-sex marriage debate
#
#
# Baby M case
# bailout outrage
# Bakke case
#
# banks and financial firms: awarding of bonuses by
# targets of bailout outrage
# as “too big to fail”
#
# Bear Stearns
#
# beggar roundups, Bentham’s proposal
# benefit-based aspect of obligations
# Bentham, Jeremy: background
# comparison with Immanuel Kant
# comparison with John Stuart Mill
# Panopticon proposal
# pauper management scheme
# preservation of corpse
# reasoning regarding utilitarianism
# see also utilitarianism
# Bergeron, Harrison
# Better Business Bureau
# birth order
#
# Blackwater Worldwide
# Boswell, James
# Boudreau, Tyler E.
#
# Brandes, Bernd-Jurgen
# Brown, Sherrod
# Buffett, Warren
# Bulger, James (Whitey)
#
# Bulger, William
# Bush, George W.
#
# Buy American provision
#
#
# cannibalism: consensual
# lifeboat case
#
# Capitalism and Freedom (Friedman)
#
# Carnegie, Andrew
# caste systems
#
# casual sex, Kant’s case against
#
# categorical imperative: comparison with hypothetical imperative
# defined
#
# and false promises
# formula of humanity as an end
# formula of universal law
# and free will
# and Golden Rule
# relationship to morality
# and suicide
#
#
#
# Chamberlain, Wilt
# Charley (hurricane)
# cheerleader example
# Cheney, Richard
# choosing self, the
# Christians, throwing to lions
#
# cigarettes, see smoking, Philip Morris cost-benefit analysis
#
# citizenship
#
# Aristotle’s view of
#
# civic obligations: military service vs. jury duty
# Rousseau’s view
# ways of discharging
# civic virtue:
#
# Aristotle’s view of
# erosion
#
# Civil War, conscripting soldiers
# see also Lee, Robert E.
#
# Cleveland, Grover
# Clinton, Bill
#
# collective responsibility: comparison with moral individualism
# compensatory case for affirmative action
# obligations of solidarity
# public apology question
#
# colleges and universities: arguments about purpose
#
# auctioning admissions
#
# mission question
#
# promoting diversity
#
# question of purpose
#
# see also affirmative action
#
# commercial surrogacy
#
# common currency of value: girls of St. Anne’s College
# Mill’s writings
#
# as objection to utilitarianism
#
# Thorndike’s survey
#
# see also cost-benefit analysis
#
# common good
#
# and abortion debate
#
# cultivating virtue and reasoning about
#
# as diversity rationale
#
# inequality, solidarity, and civic virtue as themes
# and justice
#
# moral limits of markets theme
# politics of moral engagement
# and role of religion in politics
# sacrifice and service as themes
# and same-sex marriage debate
# and stem cell research debate
# communitarians
# community
#
# compensation, worker
#
# compensatory argument, in affirmative action debate
# conscription
#
# allowing draftees to hire substitutes
# consensual cannibalism
# consent: as aspect of obligations
#
#
#
# Constitution as social contract
# and contracts
# Hume’s view
# hypothetical
#
# marriage contract example
#
# moral limits
#
# obligations beyond
#
# tainted
#
# unnecessary
#
# Constant, Benjamin
#
# Constitution of 1787: fairness of
#
# as social contract
#
# Constitution of Liberty, The (Hayek)
#
# contracts: and consent
#
# fairness in
#
# ideals behind moral force
# moral limits
#
# and Rawls’s veil of ignorance
# see also social contract
# surrogate pregnancies
# Conyers, John
#
# cost-benefit analysis: air pollution standards case
# defined
#
# exploding gas tanks case
# lung cancer case
# Craig, Gregory
# Crist, Charlie
# Cuomo, Andrew
#
#
# democrats, Aristotle’s view
#
# designated-hitter rule, in baseball
#
# difference principle: defined
#
# effort issue
#
# incentives issue
#
# and inequalities
#
# objections to
#
# Rawls’s case for
#
# and veil of ignorance
#
# vision of equality in
#
# discrimination
#
# distributive justice: Aristotle’s view
#
# initial holdings
#
# Michael Jordan example
#
# and moral desert
#
# Nozick’s challenge
#
# Rawls’s view
#
# rival theories
#
# in transfers
#
# diversity, promoting, as affirmative action argument
#
# Dodia, Suman
#
# Dorgan, Byron
#
# drafting vs. hiring soldiers
#
# duty: and categorical imperative
#
# comparison with inclination
#
#
#
# relationship to autonomy
# respect as
# see also obligations
# Dworkin, Ronald
#
#
# economic inequality
# economic stimulus
#
# effort, as issue with difference principle
#
# egalitarianism: liberal proponents
#
# and Rawls’s difference principle
#
# as theory of distribution justice
#
# in Vonnegut short story
#
# empirical beings
#
# entitlements
#
# Environmental Protection Agency
# Ethiopian Jews
# executive compensation
# exploding gas tanks
#
#
# failure, bailout bonuses seen as rewarding
#
# fairness: in college admissions
#
# in contracts
#
# and racial preferences
#
# and U.S. Constitution of 1787
#
# in voluntary agreements
#
# and volunteer army
#
# false promises
#
# Falwell, Jerry
#
# family obligations
#
# Federal Express, Blackwater comparison with
# feudal aristocracies
#
# financial firms, see banks and financial firms
# fit
#
# flute playing
# Ford Motor Company
# foreign legions
#
# free market: with formal equality of opportunity
#
# Friedman’s view
#
# Nozick’s defense
#
# and price gouging
#
# see also libertarianism
#
# markets, unfettered
#
# Free to Choose (Friedman)
#
# free will
#
# see also autonomy
# freedom: as approach to justice
# autonomy vs. heteronomy
#
# and categorical imperative vs. hypothetical imperative
# compared with virtue
# Kant’s view
#
# and moral individualism
# Rawls’s view
# relationship to community
#
#
#
# relationship to good life
# relationship to intelligible world
# relationship to morality
# Sprite analogy
#
# freedom of choice: and abortion debate
#
# as basis for just society
#
# and same-sex marriage
#
# see also libertarianism
#
# French Foreign Legion
#
# French resistance, World War II
#
# Friedman, Milton: defense of free-market economy
#
# as libertarian
#
# Friedrich Wilhelm II (king of Prussia)
#
#
# Gates, Bill
#
# gay marriage, see same-sex marriage
# Germany, reparations for Nazi past
# gestational surrogacy
# Godfather, The
#
# Golden Rule, comparison with respect
# Goldwater, Barry
#
# golf, Martin court case: Aristotelian question of justice
# background
#
# determining nature of game
#
# opposition to golf cart
#
# Supreme court case
#
# good life: Aristotle and
#
# and justice
#
# Kant’s view
#
# modern view
#
# Plato’s view
#
# Rawls’s view
#
# Google
#
# Graduate Record Exam (GRE)
#
# Grassley, Charles
#
# greed: and price gouging
#
# as source of financial bailout outrage
#
# Groundwork for the Metaphysics of Morals (Kant)
#
#
# habits, Aristotle’s view
# happiness, Aristotle’s view
# “Harrison Bergeron” short story
# Hayek, Friedrich A.
#
# heteronomy, comparison with autonomy
#
# hiring vs. drafting soldiers
#
# Hobbes, Thomas
#
# Holocaust, reparations for
#
# honor
#
# Hopwood, Cheryl
# Howard, John
# human organ sales
# human rights: Kant’s case for
# libertarian view
#
#
#
# Mill’s writings
#
# relationship of respect concept to
# utilitarian view
#
# Hume, David: house repair experience
#
# view of reason
#
# view of social contract
#
# Hurricane Charley
#
# Hyde, Henry
#
# hypothetical imperative: comparison with categorical imperative
#
# defined
#
# and freedom
#
#
# immigration: arguments for limiting
#
# and inequality among nations
#
# in vitro fertilization (IVF)
#
# incentives, as issue with difference principle
#
# inclination, Kant’s comparison with duty
#
# income differentials
#
# individual rights
#
# inequality: and difference principle
# economic, and libertarianism
# growth in American life
# income
#
# informed consent
#
# injustice, as basis for financial bailout outrage
# see also apologies, public, for historic injustices
# intelligible realm, comparison with sensible realm
# involuntary servitude, conscription as
# Iraq War: and all-volunteer army
# debate over awarding Purple Heart
# role of private contractors
#
#
# Jacoby, Jeff
#
# Japan, question of apology for wartime atrocities
# Jews, see anti-Jewish quotas
# Jews, Ethiopian
#
# Jordan, Michael: distributive justice example
# and meritocracy question
# and self-ownership question
# jury duty
#
# just society, defined
# just work
#
# justice: ancient compared with modern views
#
# Aristotle’s views
#
# and autonomous self
#
# choosing behind veil of ignorance
#
# and common good
#
# freedom approach
#
# and good life
#
# honorific aspect
#
# Kant’s view
#
# meritocratic theory
#
# and price-gouging debate
#
#
#
# promoting virtue as way of thinking about
# Rawls’s view
#
# severing from moral desert
# and surrogate pregnancies
# utilitarian approach
#
#
# Kaczynski, David
# Kant, Immanuel
# on autonomy
# background
# case for human rights
#
# comparison between heteronomy and autonomy
#
# comparison with Bentham
#
# formula of humanity as an end
#
# formula of universal law
#
# supreme principle of morality
#
# and surrogacy debate
#
# views on freedom
#
# views on good life
#
# views on justice
#
# views on lying
#
# views on moral worth
#
# views on motive
#
# views on reason
#
# views on sexual morality
#
# views on suicide
#
# views on utilitarianism
#
# Kennedy, David M.
#
# Kennedy, John F.
#
# Kennedy, Robert F.
#
# Kerry, John
# Kevorkian, Jack
# kidney sales example
# King, Martin Luther, Jr.
#
# Kinsley, Michael
# Kite, Tom
#
#
# labor market, resource for filling ranks of volunteer army
#
# Le Guin, Ursula K.
#
# learning by doing, Aristotle’s view
#
# Lee, Robert E.
#
# Lewinsky, Monica
# libertarianism
#
# argument against conscription
#
# argument for contracts
#
# argument in favor of volunteer army
#
# assisted suicide example
#
# comparison with meritocratic theory of justice
#
# consensual cannibalism example
#
# and debate over same-sex marriage
#
# disagreements with
#
# and economic inequality
#
# kidney sales example
#
#
#
# Nozick’s defense
#
# and question of prostitution
#
# Rawls’s view
#
# rejected as social contract option
#
# and self-ownership question
#
# as theory of distributive justice
#
# views on human rights
#
# views on laws and policies of modern states
#
# liberty, see freedom
#
# On Liberty (Mill)
#
# individual rights
#
# lifeboat case
#
# lived narratives
#
# Locke, John
#
# and tacit consent
#
# view of the choosing self
#
# Lowell, A. Lawrence
#
# loyalty dilemmas
#
# lung cancer, and Philip Morris cost-benefit analysis
#
# Luttrell, Marcus
#
# lying, Kant’s view
#
# comparison with misleading
#
# white lies
#
#
# MacIntyre, Alasdair
# markets
# libertarian case
# and military service
# moral limits
#
# as remedy for unfairness of birth circumstances
#
# unfettered
#
# utilitarian case
#
# and Wall Street bailout ethics
# see also free market
# marriage: disestablishment proposal
# as honorific institution
# Kant’s view
#
# see also same-sex marriage
# marriage contracts
# Marshall, Margaret
# Martin, Casey
# Martin, Judith
#
# maximizing utility, see utilitarianism
# maxims, universalizing
# medals, military, see Purple Heart
# Meiwes, Armin
# mercenary armies
# meritocratic theory of justice
# Mignonette (ship)
# military, see U.S. military
# Military Order of the Purple Heart
# Mill, James
#
# Mill, John Stuart: background
# comparison with Jeremy Bentham
#
#
#
# distinguishes between higher and lower pleasures
# makes case for liberty
#
# revisions to Bentham’s doctrine of utilitarianism
# view of Kant’s universal law formula
# minimal state
#
# misleading truths, comparison with lying
#
# moral desert: comparison with entitlements to legitimate expectations
#
# detaching justice from
#
# and distributive justice
#
# and financial bailout outrage
#
# moral dilemmas
#
# Afghan goatherds dilemma
#
# finding path through
#
# lifeboat case
#
# runaway trolley scenario
#
# surrogacy contracts
#
# ticking time bomb case
#
# in Ursula Le Guin story
#
# see also loyalty dilemmas
#
# moral force, in contracts
#
# moral individualism
#
# moral law: Kant’s distinction between lies and misleading truths
# Kant’s view
#
# relationship to categorical imperative
#
# moral limits
#
# moral reasoning
#
# moral reflection
#
# moral virtue, see virtue
#
# moral worth
#
# morality: as about principle, not consequences
#
# duty vs. inclination
#
# Kant links to freedom
#
# relationship to categorical imperative
#
# as supreme principle
#
# Morgan, J. P.
#
# motive of duty
#
# motives of inclination
#
#
# narrative conception of person
# narrative quest
#
# National Highway Traffic Safety Commission
#
# national service
#
# New York City squeegee men
#
# Nicklaus, Jack
#
# Nicomachean Ethics (Aristotle)
#
# Nozick, Robert
#
#
# Obama, Barack: encourages national service
# and politics of common good
# on role of religion in politics
# signs economic stimulus bill
# views on financial bailout
#
# object standpoint, comparison with agent standpoint
#
#
#
# obligations: and affirmative action
# civic or communal
#
# consent-based compared with benefit-based
# family
#
# natural compared with voluntary
# Rawls’s view
# of solidarity
#
# oligarchs, Aristotle’s view
# Ornelas (city in Ursula Le Guin story)
#
# On Liberty (Mill)
#
# organ (human) sales
#
# outrage: over price gouging
#
# over Wall Street bonuses
#
# outsourcing pregnancy
#
# Oxford University, St. Anne’s College
#
#
# paid pregnancy
# Palmer, Arnold
# Panopticon
#
# paternalism, libertarian objections to
# patriotism, as virtue
# Paul, Ron
#
# pauper management, Bentham’s proposal
# pay differentials
# Peace Corps
#
# Pentagon: debate over awarding Purple Heart
# reasons for limiting Purple Heart award to physical injuries
# Peres, Shimon
#
# PGA (Professional Golfers’ Association)
#
# Philip Morris
#
# Plato, view of justice
#
# pleasures, higher vs. lower
#
# Political Liberalism (Rawls)
#
# politics: Aristotle’s defense of slavery
#
# Aristotle’s view
#
# modern view
#
# and nature of human beings
# purpose or telos
# Politics (Aristotle)
# post-traumatic stress disorder
# pregnancy for pay
#
# price gouging: aftermath of Florida’s Hurricane Charley
#
# justice considerations
#
# pros and cons of laws against
#
# Prince, Erik
#
# Principles of Morals and Legislation (Bentham)
#
# prisons, Bentham’s proposal
#
# procreation
#
# see also surrogate pregnancies
# prostitution, Kant’s view
# public schools
#
# Purple Heart: debate over awarding for psychological injuries
# honors sacrifice, not bravery
#
#
#
# racial discrimination
#
# racial preferences, question of fairness
#
# Rangel, Charles
#
# Rau, Johannes
#
# Rawls, John
#
# background
#
# and difference principle
# hypothetical social contract
# rejects complacence
#
# rejects moral desert as basis for distributive justice
#
# views on autonomous self
#
# views on freedom
#
# views on good life
#
# views on justice
#
# views on libertarianism
#
# views on meritocratic theory of justice
#
# views on role of religion in politics
#
# Reagan, Ronald
#
# reason: categorical vs. hypothetical imperatives
# Hobbes’s view
# Hume’s view
# Kant’s view
#
# reciprocity: as ideal behind moral force in contracts
# marriage contract example
#
# redistribution of income or wealth, libertarian objections to
#
# religion, role in politics: aspiration to neutrality
#
# Kennedy and
#
# Obama and
#
# Rawls’s view
#
# reproductive technologies
#
# respect: comparison with Golden Rule
#
# Kantian view
#
# relationship to doctrine of universal human rights
# rights
#
# Robertson, Pat
# Roosevelt, Franklin D.
#
# Rousseau, Jean-Jacques: as defender of patriotism
#
# makes case for conscription
#
# Rowlandson, Thomas
#
# runaway trolley scenario
#
# Kantian view
#
# utilitarian view
#
#
# salary differentials
#
# same-sex marriage
#
# SAT (Scholastic Aptitude Test)
#
# Scalia, Antonin
#
# self-ownership
#
# and question of prostitution
#
# sensible realm, comparison with intelligible realm
#
# sex, casual, Kant’s case against
#
# Shakespeare, William, compared with The Simpsons
#
# Sharlot, Michael
#
#
#
# Simpsons, The, compared with Shakespeare
# slavery: Aristotle’s defense
# as coercive
# conscription as
#
# question of U.S. apology and reparations
# teleological view
# Smartt, Callie
#
# smoking, Philip Morris cost-benefit analysis
# social contract: Hume’s view
# incompatibility with libertarianism
# incompatibility with utilitarianism
# and Kant’s view of justice
# moral limits
# Rawls’s hypothetical
# Social Contract (Rousseau)
#
# Socrates
#
# soldiers: and Afghan goatherds dilemma
#
# debate over awarding of Purple Heart to
#
# drafting vs. hiring
#
# solidarity: obligations
#
# undermining
#
# Sorkow, Harvey R.
#
# Sowell, Thomas
# Spar, Deborah
# spelling bee hero
# sports, rules in
# Sprite analogy
# squeegee men
#
# standardized tests, testing gap
# St. Anne’s College, Oxford University
# Stardust Memories (movie)
#
# Starrett City apartment complex, Brooklyn
#
# Steinbrenner, George
#
# stem cell research debate
#
# Stern, Melissa
#
# Stern, William and Elizabeth
#
# Stevens, John Paul
#
# suicide: assisted
#
# and categorical imperative
#
# Supreme Court: and affirmative action
#
# Bakke case
#
# Martin golf case
#
# surrogate pregnancies: Baby M contract
#
# gestational
#
# growth in market
#
# justice considerations
#
# outsourcing
#
# tainted consent objection
# valuation objection
# Sweatt, Herman Marion
#
#
# tainted consent
# Taliban
#
# taxation: comparison with forced labor
#
#
#
# majority vs. individual rights
# objections
# and volunteer army
# Taylor, Harriet
# Teach for America
# teleological thinking
# as aspect of justice
# and slavery
# telos, defined
#
# terrorists, suspected, torturing of
# testing gap, standardized tests
# Thatcher, Margaret
# A Theory of Justice (Rawls)
# Thorndike, Edward
# ticking time bomb case
# torturing suspected terrorists
# trolley, see runaway trolley scenario
# truth, see lying, Kant’s view
#
#
# Unabomber
# unfettered markets
# see also price gouging
#
# United States, debate over public apologies and reparations
# universal law
#
# U.S. Constitution: fairness of
# as social contract
#
# U.S. Environmental Protection Agency
#
# U.S. military: and Afgan goatherds dilemma
#
# drafting vs. hiring soldiers
#
# Purple Heart debate
#
# use of private contractors
#
# U.S. Supreme Court: and affirmative action
#
# Bakke case
#
# Martin golf case
#
# utilitarianism
#
# as approach to justice
#
# argument against conscription
#
# argument in favor of volunteer army
#
# case for affirmative action
#
# case for contracts
#
# distinguishing between higher and lower pleasures
#
# and economic inequality
#
# founder Bentham’s reasoning
#
# Kant’s view
#
# Mill’s writing
#
# objection regarding common currency of rights
# objection regarding individual rights
# question of throwing Christians to lions
# question of torturing suspected terrorists
# rejected as social contract option
# rejecting behind veil of ignorance
# and runaway trolley
# utility vs. higher norms
# view of human rights
#
#
#
# WWF vs. Shakespeare vs.

# %%
# manually remove section "NOTES", "ACKNOWLEDGEMENTS" and "INDEX"

# %%
# manually split the book by chapter

# %%
# POS + lemming for better lemming performance:
# The lemmatizer requires the correct POS tag to be accurate, 
# if you use the default settings of the WordNetLemmatizer.lemmatize(), the default tag is noun
# https://github.com/nltk/nltk/blob/develop/nltk/stem/wordnet.py#L39 
wnl = WordNetLemmatizer()

justice_lemmed = list()
for sen in sentences:
    sens = list()
    for word, tag in pos_tag(word_tokenize(sen)):
        wntag = tag[0].lower()
        wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
        lemma = wnl.lemmatize(word, wntag) if wntag else word
        sens.append(lemma)
    justice_lemmed.append(sens)

print(len(justice_lemmed))
# Out:
# 5388

# %%
print(justice_lemmed[:10])
# Out:
# [['Justice', 'Michael', 'Sandel', 'This', 'book', 'be', 'produce', 'in', 'EPUB', 'format', 'by', 'the', 'Internet', 'Archive', '.'], ['The', 'book', 'page', 'be', 'scan', 'and', 'convert', 'to', 'EPUB', 'format', 'automatically', '.'], ['This', 'process', 'rely', 'on', 'optical', 'character', 'recognition', ',', 'and', 'be', 'somewhat', 'susceptible', 'to', 'error', '.'], ['The', 'book', 'may', 'not', 'offer', 'the', 'correct', 'reading', 'sequence', ',', 'and', 'there', 'may', 'be', 'weird', 'character', ',', 'non-words', ',', 'and', 'incorrect', 'guess', 'at', 'structure', '.'], ['Some', 'page', 'number', 'and', 'header', 'or', 'footer', 'may', 'remain', 'from', 'the', 'scanned', 'page', '.'], ['The', 'process', 'which', 'identifies', 'image', 'might', 'have', 'find', 'stray', 'mark', 'on', 'the', 'page', 'which', 'be', 'not', 'actually', 'image', 'from', 'the', 'book', '.'], ['The', 'hidden', 'page', 'number', 'which', 'may', 'be', 'available', 'to', 'your', 'ereader', 'corresponds', 'to', 'the', 'numbered', 'page', 'in', 'the', 'print', 'edition', ',', 'but', 'be', 'not', 'an', 'exact', 'match', ';', 'page', 'number', 'will', 'increment', 'at', 'the', 'same', 'rate', 'as', 'the', 'corresponding', 'print', 'edition', ',', 'but', 'we', 'may', 'have', 'start', 'number', 'before', 'the', 'print', 'book', "'s", 'visible', 'page', 'number', '.'], ['The', 'Internet', 'Archive', 'be', 'work', 'to', 'improve', 'the', 'scanning', 'process', 'and', 'result', 'book', ',', 'but', 'in', 'the', 'meantime', ',', 'we', 'hope', 'that', 'this', 'book', 'will', 'be', 'useful', 'to', 'you', '.'], ['The', 'Internet', 'Archive', 'be', 'found', 'in', '1996', 'to', 'build', 'an', 'Internet', 'library', 'and', 'to', 'promote', 'universal', 'access', 'to', 'all', 'knowledge', '.'], ['The', 'Archive', "'s", 'purpose', 'include', 'offer', 'permanent', 'access', 'for', 'researcher', ',', 'historian', ',', 'scholar', ',', 'people', 'with', 'disability', ',', 'and', 'the', 'general', 'public', 'to', 'historical', 'collection', 'that', 'exist', 'in', 'digital', 'format', '.']]

# %%
justice_lower_words = list()

for s in justice_lemmed:
    #Lowercase
    sen = [w.lower() for w in s]
    # remove punctuations
    sentence = [w for w in sen if re.search('^[a-z]+$',w)]
    # remove words with length < 3
    sentence1 = [w for w in sentence if len(w)>3]
    # remove empty lists
    if len(sentence1) > 0:
        justice_lower_words.append(sentence1)
print(len(justice_lower_words))
print(justice_lower_words[:10])
# Out:
# 4741
# [['justice', 'michael', 'sandel', 'this', 'book', 'produce', 'epub', 'format', 'internet', 'archive'], ['book', 'page', 'scan', 'convert', 'epub', 'format', 'automatically'], ['this', 'process', 'rely', 'optical', 'character', 'recognition', 'somewhat', 'susceptible', 'error'], ['book', 'offer', 'correct', 'reading', 'sequence', 'there', 'weird', 'character', 'incorrect', 'guess', 'structure'], ['some', 'page', 'number', 'header', 'footer', 'remain', 'from', 'scanned', 'page'], ['process', 'which', 'identifies', 'image', 'might', 'have', 'find', 'stray', 'mark', 'page', 'which', 'actually', 'image', 'from', 'book'], ['hidden', 'page', 'number', 'which', 'available', 'your', 'ereader', 'corresponds', 'numbered', 'page', 'print', 'edition', 'exact', 'match', 'page', 'number', 'will', 'increment', 'same', 'rate', 'corresponding', 'print', 'edition', 'have', 'start', 'number', 'before', 'print', 'book', 'visible', 'page', 'number'], ['internet', 'archive', 'work', 'improve', 'scanning', 'process', 'result', 'book', 'meantime', 'hope', 'that', 'this', 'book', 'will', 'useful'], ['internet', 'archive', 'found', 'build', 'internet', 'library', 'promote', 'universal', 'access', 'knowledge'], ['archive', 'purpose', 'include', 'offer', 'permanent', 'access', 'researcher', 'historian', 'scholar', 'people', 'with', 'disability', 'general', 'public', 'historical', 'collection', 'that', 'exist', 'digital', 'format']]

# %%
# stop words removal + stemming
stemmer = PorterStemmer()

stop_list = stopwords.words('english')
justice_stemmed = list()
for l in justice_lower_words:
    # lemmed = [lemmatizer.lemmatize(w) for w in sen]
    sen = [w for w in l if w not in stop_list]
    stemmed = [stemmer.stem(w) for w in sen]
    justice_stemmed.append(stemmed)
print(len(justice_stemmed))
print(justice_stemmed[:10])
# Out:
# 4741
# [['justic', 'michael', 'sandel', 'book', 'produc', 'epub', 'format', 'internet', 'archiv'], ['book', 'page', 'scan', 'convert', 'epub', 'format', 'automat'], ['process', 'reli', 'optic', 'charact', 'recognit', 'somewhat', 'suscept', 'error'], ['book', 'offer', 'correct', 'read', 'sequenc', 'weird', 'charact', 'incorrect', 'guess', 'structur'], ['page', 'number', 'header', 'footer', 'remain', 'scan', 'page'], ['process', 'identifi', 'imag', 'might', 'find', 'stray', 'mark', 'page', 'actual', 'imag', 'book'], ['hidden', 'page', 'number', 'avail', 'eread', 'correspond', 'number', 'page', 'print', 'edit', 'exact', 'match', 'page', 'number', 'increment', 'rate', 'correspond', 'print', 'edit', 'start', 'number', 'print', 'book', 'visibl', 'page', 'number'], ['internet', 'archiv', 'work', 'improv', 'scan', 'process', 'result', 'book', 'meantim', 'hope', 'book', 'use'], ['internet', 'archiv', 'found', 'build', 'internet', 'librari', 'promot', 'univers', 'access', 'knowledg'], ['archiv', 'purpos', 'includ', 'offer', 'perman', 'access', 'research', 'historian', 'scholar', 'peopl', 'disabl', 'gener', 'public', 'histor', 'collect', 'exist', 'digit', 'format']]

# %%
# Get the top-20 most frequent words in the file. User FreqDist an most_common
temp = list()
for sen in justice_stemmed:
    for word in sen:
        temp.append(word)

fdist_justice = FreqDist(temp).most_common(50)
# print(fdist_justice.most_common(50))

wordcloud = WordCloud(width=1600, height=800, background_color='white').generate(str(temp))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 50 Most Common Words', fontsize=100)
plt.tight_layout(pad=0)
plt.show()

# Number of *unique* words in the file
filtered_word_freq = dict((word, freq) for word, freq in fdist_justice.items() if not word.isdigit())
print(len(filtered_word_freq))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [53], line 19
#      16 plt.show()
#      18 # Number of *unique* words in the file
# ---> 19 filtered_word_freq = dict((word, freq) for word, freq in fdist_justice.items() if not word.isdigit())
#      20 print(len(filtered_word_freq))
#
# AttributeError: 'list' object has no attribute 'items'

# %%
x, y = zip(*fdist_justice)
plt.figure(figsize=(50,30))
plt.margins(0.02)
plt.bar(x, y)
plt.xlabel('Words', fontsize=50)
plt.ylabel('Frequency of Words', fontsize=50)
plt.yticks(fontsize=40)
plt.xticks(rotation=60, fontsize=40)
plt.title('Frequency of 50 Most Common Words', fontsize=60)
plt.show()

# %%
# vectorise the words
justice_dict = corpora.Dictionary(justice_stemmed)
token_to_id = justice_dict.token2id
print(type(token_to_id))
# print(token_to_id) ？

# Converting all documents in SGNews Apr2012 to a list of sparse vectors.
justice_vecs = [justice_dict.doc2bow(doc) for doc in justice_stemmed]
print(justice_vecs[-1][-1])

# compare similarity (not done)
sample_index = similarities.SparseMatrixSimilarity(justice_vecs, 5471)
# Out:
# <class 'dict'>
# (5471, 1)
