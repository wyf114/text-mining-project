# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk import pos_tag, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

import gensim
from gensim import corpora
from gensim import similarities
from gensim import models
from gensim.models import CoherenceModel

import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re
import os
import preprocess

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Extract Train Data

# %%
# Define the directory where the books are located
books_directory = "Data/Train"

# Create a list to store the text data of each book
book_texts = []

# Loop through each file in the directory
for filename in os.listdir(books_directory):
    if filename.endswith('.txt'):
        with open(os.path.join(books_directory, filename), "r", encoding="utf8", errors='ignore') as file:
            book_text = file.read()
            book_texts.append(book_text)

# %% [markdown]
# # Preprocessing

# %%
def load_corpus(dir):
    corpus = nltk.corpus.PlaintextCorpusReader(dir, '.+\.txt')
    return corpus

def corpus2docs(corpus):
    docs_token=[]
    for doc in corpus:
        doc1 = nltk.word_tokenize(doc)
        docs_token.append(doc1)

    docs_lower = [[w.lower() for w in doc] for doc in docs_token]
    docs_alpha = [[w for w in doc if re.search('^[a-z]+$', w)] for doc in docs_lower]
    
    lemmatizer = WordNetLemmatizer()
    docs_lem = [[lemmatizer.lemmatize(word, tag[0].lower()) for word, tag in pos_tag(doc, tagset='universal') if tag[0].lower() in ['a', 'r', 'n', 'v']] for doc in docs_alpha ]

    return docs_lem

def docs2vecs(docs, dictionary):
    vecs1 = [dictionary.doc2bow(doc) for doc in docs]
    return vecs1

# %%
doc_cleaned = corpus2docs(book_texts)
doc_cleaned[0][:10]

# %% [markdown]
# ## Bigrams and Trigrams

# %%
stop_list = stopwords.words('english')        
stop_list += ['project', 'gutenberg', 'ebook', 'www.gutenberg.org', 'from', 'subject', 'would', 'etext', 're', 'edu', 'use', 'http', 'www',
             'said', 'denotes']

# Build the bigram and trigram models
bigram = gensim.models.Phrases(doc_cleaned, min_count=5, threshold=50) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[doc_cleaned], threshold=50)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

def make_bigrams(texts):
    bigram = [bigram_mod[doc] for doc in texts]
    docs_stop = [[w for w in doc if w not in stop_list] for doc in bigram] 
    bigram_cleaned = [[w for w in doc if len(w)>3] for doc in docs_stop]
                     
    return bigram_cleaned

def make_trigrams(texts):
    trigram = [trigram_mod[bigram_mod[doc]] for doc in texts]
    docs_stop = [[w for w in doc if w not in stop_list] for doc in trigram] 
    trigram_cleaned = [[w for w in doc if len(w)>3] for doc in docs_stop]
    return trigram_cleaned

# %%
docs_bigrams = make_bigrams(doc_cleaned)
# docs_bigrams
data_bigrams_trigrams = make_trigrams(docs_bigrams)
# docs_trigrams
data_bigrams_trigrams[0][0:20]
# Out:
# ['project_gutenberg',
#  'utilitarianism',
#  'john_stuart_mill',
#  'anyone_anywhere',
#  'cost',
#  'almost_restriction_whatsoever',
#  'copy',
#  'give',
#  'away',
#  'term',
#  'project_gutenberg_license_include',
#  'ebook_online',
#  'title',
#  'utilitarianism',
#  'author',
#  'john_stuart_mill',
#  'release_date',
#  'february',
#  'ebook_language_english',
#  'character_set_encode']

# %% [markdown]
# ## TF-IDF Removal

# %%
from gensim.models import TfidfModel

id2word = corpora.Dictionary(data_bigrams_trigrams)
texts = data_bigrams_trigrams

corpus = [id2word.doc2bow(text) for text in texts]
# print(corpus[0][0:20])

tfidf = models.TfidfModel(corpus, id2word=id2word)

low_value = 0.03
words = []
words_missing_in_tfidf = []
for i in range(0, len(corpus)):
    bow = corpus[i]
    low_value_words = [] #reinitialize to be safe. You can skip this.
    tfidf_ids = [id for id, value in tfidf[bow]]
    bow_ids = [id for id, value in bow]
    low_value_words = [id for id, value in tfidf[bow] if value < low_value]
    drops = low_value_words+words_missing_in_tfidf
    for item in drops:
        words.append(id2word[item])
    words_missing_in_tfidf = [id for id in bow_ids if id not in tfidf_ids] # The words with tf-idf socre 0 will be missing

    new_bow = [b for b in bow if b[0] not in low_value_words and b[0] not in words_missing_in_tfidf]  
    corpus[i] = new_bow

# %% [markdown]
# # Topic Modeling

# %%
print('Number of unique tokens: %d' % len(id2word))
print('Number of articles: %d' % len(corpus))
# Out:
# Number of unique tokens: 38033
# Number of articles: 46

# %%
print(id2word)

# %% [markdown]
# ## LDA Model

# %%
# Build LDA model
lda_multicore_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=10, 
                                       random_state=42,
                                       chunksize=100,
                                       passes=10,
                                       per_word_topics=True)

topics = lda_multicore_model.show_topics(10, 5)
for i in range(10):
    print(topics[i])
# Out:
# (0, '0.017*"king" + 0.014*"eugenics" + 0.013*"witch" + 0.012*"devil" + 0.012*"marriage"')
# (1, '0.040*"government" + 0.033*"city" + 0.028*"plato" + 0.026*"soul" + 0.026*"citizen"')
# (2, '0.052*"object" + 0.043*"sensation" + 0.036*"consciousness" + 0.026*"physical" + 0.019*"exist"')
# (3, '0.054*"woman" + 0.032*"marriage" + 0.024*"wife" + 0.022*"love" + 0.021*"marry"')
# (4, '0.071*"child" + 0.056*"sexual" + 0.047*"woman" + 0.028*"girl" + 0.016*"mother"')
# (5, '0.212*"dream" + 0.059*"denote" + 0.042*"woman" + 0.022*"foretells" + 0.020*"foretell"')
# (6, '0.048*"country" + 0.033*"price" + 0.026*"labour" + 0.024*"trade" + 0.023*"quantity"')
# (7, '0.031*"image" + 0.022*"sensation" + 0.019*"belief" + 0.016*"young" + 0.015*"social"')
# (8, '0.073*"conception" + 0.033*"pure" + 0.030*"phenomenon" + 0.026*"cognition" + 0.025*"intuition"')
# (9, '0.075*"zarathustra" + 0.065*"thou" + 0.049*"hath" + 0.040*"thee" + 0.039*"unto"')

# %%
# Compute Perplexity
perplex= lda_multicore_model.log_perplexity(corpus, total_docs=None)
# a measure of how good the model is. lower the better.

print('\nPerplexity for LDAMulticoreModel: ', perplex)
# Out:
# Perplexity for LDAMulticoreModel:  -5.55803700836104

# %%
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_multicore_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score LDAMulticoreModel: ', coherence_lda)
# Out:
# Coherence Score LDAMulticoreModel:  0.5153706404027873

# %%
# Can take a long time to run. In this case we are going to  k_max=10.
import datetime
print(datetime.datetime.now())

from gensim.models import CoherenceModel

model_list = []
coherence_values = []
model_topics = []

for num_topics in range(2, 6):
    lda_x = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics, 
                                       random_state=42,
                                       chunksize=100,
                                       passes=10)
    coherence_model_lda = CoherenceModel(model=lda_x, texts=texts, dictionary=id2word, coherence='c_v')
    coherence_values.append(coherence_model_lda.get_coherence())
 
    model_topics.append(num_topics) 
    model_list.append(lda_x)
    print("#Topics: " + str(num_topics) + ", Score: " + str(coherence_values[-1]))

print(datetime.datetime.now())
# Out:
# 2023-04-02 15:27:37.572272
# #Topics: 2, Score: 0.3536084476549796
# #Topics: 3, Score: 0.35018841605293183
# #Topics: 4, Score: 0.3879738755865584
# #Topics: 5, Score: 0.5435572102468758
# 2023-04-02 15:29:54.664820

# %%
# Show graph

import matplotlib.pyplot as plt

limit=6; start=2; step=1;
x = range(start, limit)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3536
# Num Topics = 3  has Coherence Value of 0.3502
# Num Topics = 4  has Coherence Value of 0.388
# Num Topics = 5  has Coherence Value of 0.5436

# %% [markdown]
# ## Hyper-Parameter Tuning and Evaluation

# %%
# hyper-perameter tuning (alpha and beta)
def compute_coherence_values(corpus, dictionary, k, a, b):
    
    lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=k, 
                                           random_state=42,
                                           chunksize=100,
                                           passes=10,
                                           alpha=a,
                                           eta=b)
    
    coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=dictionary, coherence='c_v')
    
    return coherence_model_lda.get_coherence()

# %%
# setup
import numpy as np

from gensim.models import CoherenceModel

model_list = []
coherence_values = []
perplexity_values = []
model_topics = []
alpha_result = []
beta_result = []

# Alpha parameter
alpha = list(np.arange(0.01, 1, 0.3))
alpha.append('symmetric')
alpha.append('asymmetric')

# Beta parameter
beta = list(np.arange(0.01, 1, 0.3))
beta.append('symmetric')

# %%
# Can take a few hours to run.
import datetime
import numpy as np
from gensim.models import CoherenceModel

print(datetime.datetime.now())

for a in alpha:
    for b in beta:
        for num_topics in range(2, 6):
            cv = compute_coherence_values(corpus=corpus, dictionary=id2word,k=num_topics, a=a, b=b) 
            pv = lda_multicore_model.log_perplexity(corpus, total_docs=None)
            model_topics.append(num_topics)    
            coherence_values.append(cv)  
            perplexity_values.append(pv)
            alpha_result.append(a)
            beta_result.append(b)
            print("#Topics: " + str(num_topics) + ", CV Score: " + str(coherence_values[-1]) + ", PV Score: " + str(perplexity_values[-1]) + ", Alpha: " + str(alpha_result[-1]) + ", Beta: " + str(beta_result[-1]))
            
print(datetime.datetime.now())
# Out:
# 2023-04-02 15:34:40.133854
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558037003917111, Alpha: 0.01, Beta: 0.01
# #Topics: 3, CV Score: 0.41986292638697503, PV Score: -5.558037003830284, Alpha: 0.01, Beta: 0.01
# #Topics: 4, CV Score: 0.4165450446379923, PV Score: -5.558036992620346, Alpha: 0.01, Beta: 0.01
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558036986794294, Alpha: 0.01, Beta: 0.01
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558037020818071, Alpha: 0.01, Beta: 0.31
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037020191434, Alpha: 0.01, Beta: 0.31
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037028759486, Alpha: 0.01, Beta: 0.31
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.5580370141416715, Alpha: 0.01, Beta: 0.31
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037001618207, Alpha: 0.01, Beta: 0.61
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558036984211426, Alpha: 0.01, Beta: 0.61
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.5580370195428594, Alpha: 0.01, Beta: 0.61
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558037012284626, Alpha: 0.01, Beta: 0.61
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558036989315363, Alpha: 0.01, Beta: 0.9099999999999999
# #Topics: 3, CV Score: 0.34448896557256486, PV Score: -5.558036987233681, Alpha: 0.01, Beta: 0.9099999999999999
# #Topics: 4, CV Score: 0.34876280047752867, PV Score: -5.558037011904875, Alpha: 0.01, Beta: 0.9099999999999999
# #Topics: 5, CV Score: 0.3678511744412175, PV Score: -5.558036974968535, Alpha: 0.01, Beta: 0.9099999999999999
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037021870191, Alpha: 0.01, Beta: symmetric
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.5580369886179675, Alpha: 0.01, Beta: symmetric
# #Topics: 4, CV Score: 0.3879738755865584, PV Score: -5.5580370050276295, Alpha: 0.01, Beta: symmetric
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558036972076365, Alpha: 0.01, Beta: symmetric
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.5580370041846985, Alpha: 0.31, Beta: 0.01
# #Topics: 3, CV Score: 0.41986292638697503, PV Score: -5.558037007092627, Alpha: 0.31, Beta: 0.01
# #Topics: 4, CV Score: 0.4165450446379923, PV Score: -5.5580370029821, Alpha: 0.31, Beta: 0.01
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037008185842, Alpha: 0.31, Beta: 0.01
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558036988596956, Alpha: 0.31, Beta: 0.31
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037001459693, Alpha: 0.31, Beta: 0.31
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.55803700938844, Alpha: 0.31, Beta: 0.31
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.5580369958567335, Alpha: 0.31, Beta: 0.31
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037031257072, Alpha: 0.31, Beta: 0.61
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037000091784, Alpha: 0.31, Beta: 0.61
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037018640602, Alpha: 0.31, Beta: 0.61
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558037013752958, Alpha: 0.31, Beta: 0.61
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037001251432, Alpha: 0.31, Beta: 0.9099999999999999
# #Topics: 3, CV Score: 0.34448896557256486, PV Score: -5.558036991463788, Alpha: 0.31, Beta: 0.9099999999999999
# #Topics: 4, CV Score: 0.34876280047752867, PV Score: -5.558037021050742, Alpha: 0.31, Beta: 0.9099999999999999
# #Topics: 5, CV Score: 0.3678511744412175, PV Score: -5.558036993769798, Alpha: 0.31, Beta: 0.9099999999999999
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037001981891, Alpha: 0.31, Beta: symmetric
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037005141957, Alpha: 0.31, Beta: symmetric
# #Topics: 4, CV Score: 0.3879738755865584, PV Score: -5.558037004195204, Alpha: 0.31, Beta: symmetric
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037026676259, Alpha: 0.31, Beta: symmetric
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558036989784105, Alpha: 0.61, Beta: 0.01
# #Topics: 3, CV Score: 0.41986292638697503, PV Score: -5.558037025302788, Alpha: 0.61, Beta: 0.01
# #Topics: 4, CV Score: 0.4165450446379923, PV Score: -5.558037029716745, Alpha: 0.61, Beta: 0.01
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037014259706, Alpha: 0.61, Beta: 0.01
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558037003633147, Alpha: 0.61, Beta: 0.31
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558036998904017, Alpha: 0.61, Beta: 0.31
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558036993487688, Alpha: 0.61, Beta: 0.31
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558037022782336, Alpha: 0.61, Beta: 0.31
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037008044323, Alpha: 0.61, Beta: 0.61
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037022871944, Alpha: 0.61, Beta: 0.61
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037002637573, Alpha: 0.61, Beta: 0.61
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558036996028533, Alpha: 0.61, Beta: 0.61
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558036991774634, Alpha: 0.61, Beta: 0.9099999999999999
# #Topics: 3, CV Score: 0.34448896557256486, PV Score: -5.558037001192416, Alpha: 0.61, Beta: 0.9099999999999999
# #Topics: 4, CV Score: 0.34876280047752867, PV Score: -5.558037011151551, Alpha: 0.61, Beta: 0.9099999999999999
# #Topics: 5, CV Score: 0.3678511744412175, PV Score: -5.558036997981984, Alpha: 0.61, Beta: 0.9099999999999999
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.55803701182639, Alpha: 0.61, Beta: symmetric
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.5580369878794755, Alpha: 0.61, Beta: symmetric
# #Topics: 4, CV Score: 0.3879738755865584, PV Score: -5.558037000066138, Alpha: 0.61, Beta: symmetric
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037007618222, Alpha: 0.61, Beta: symmetric
# #Topics: 2, CV Score: 0.3261254061364326, PV Score: -5.558037011421919, Alpha: 0.9099999999999999, Beta: 0.01
# #Topics: 3, CV Score: 0.41986292638697503, PV Score: -5.5580370074646535, Alpha: 0.9099999999999999, Beta: 0.01
# #Topics: 4, CV Score: 0.4165450446379923, PV Score: -5.558036972423673, Alpha: 0.9099999999999999, Beta: 0.01
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558036977814355, Alpha: 0.9099999999999999, Beta: 0.01
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.5580369972648125, Alpha: 0.9099999999999999, Beta: 0.31
# #Topics: 3, CV Score: 0.3437468215802399, PV Score: -5.5580370358925775, Alpha: 0.9099999999999999, Beta: 0.31
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037007670442, Alpha: 0.9099999999999999, Beta: 0.31
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558036999109188, Alpha: 0.9099999999999999, Beta: 0.31
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037021131081, Alpha: 0.9099999999999999, Beta: 0.61
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558036997542287, Alpha: 0.9099999999999999, Beta: 0.61
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037041692366, Alpha: 0.9099999999999999, Beta: 0.61
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558037029505703, Alpha: 0.9099999999999999, Beta: 0.61
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558036999157391, Alpha: 0.9099999999999999, Beta: 0.9099999999999999
# #Topics: 3, CV Score: 0.34448896557256486, PV Score: -5.558037005098698, Alpha: 0.9099999999999999, Beta: 0.9099999999999999
# #Topics: 4, CV Score: 0.34876280047752867, PV Score: -5.5580370456317105, Alpha: 0.9099999999999999, Beta: 0.9099999999999999
# #Topics: 5, CV Score: 0.3678511744412175, PV Score: -5.558037002526335, Alpha: 0.9099999999999999, Beta: 0.9099999999999999
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037003783317, Alpha: 0.9099999999999999, Beta: symmetric
# #Topics: 3, CV Score: 0.3437468215802399, PV Score: -5.558037015261151, Alpha: 0.9099999999999999, Beta: symmetric
# #Topics: 4, CV Score: 0.3879738755865584, PV Score: -5.558037003601321, Alpha: 0.9099999999999999, Beta: symmetric
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037008384833, Alpha: 0.9099999999999999, Beta: symmetric
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.5580369973374255, Alpha: symmetric, Beta: 0.01
# #Topics: 3, CV Score: 0.41986292638697503, PV Score: -5.558037008248567, Alpha: symmetric, Beta: 0.01
# #Topics: 4, CV Score: 0.4165450446379923, PV Score: -5.558036988504876, Alpha: symmetric, Beta: 0.01
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558036993970644, Alpha: symmetric, Beta: 0.01
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558036999010929, Alpha: symmetric, Beta: 0.31
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037015887479, Alpha: symmetric, Beta: 0.31
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037016499902, Alpha: symmetric, Beta: 0.31
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.5580370284739775, Alpha: symmetric, Beta: 0.31
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037011589702, Alpha: symmetric, Beta: 0.61
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.55803700898984, Alpha: symmetric, Beta: 0.61
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558036998854269, Alpha: symmetric, Beta: 0.61
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558037019011701, Alpha: symmetric, Beta: 0.61
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.5580370047594245, Alpha: symmetric, Beta: 0.9099999999999999
# #Topics: 3, CV Score: 0.34448896557256486, PV Score: -5.558036990084754, Alpha: symmetric, Beta: 0.9099999999999999
# #Topics: 4, CV Score: 0.34876280047752867, PV Score: -5.558037018285878, Alpha: symmetric, Beta: 0.9099999999999999
# #Topics: 5, CV Score: 0.3678511744412175, PV Score: -5.5580370164458275, Alpha: symmetric, Beta: 0.9099999999999999
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037004413044, Alpha: symmetric, Beta: symmetric
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037011150624, Alpha: symmetric, Beta: symmetric
# #Topics: 4, CV Score: 0.3879738755865584, PV Score: -5.558037035960864, Alpha: symmetric, Beta: symmetric
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037008941637, Alpha: symmetric, Beta: symmetric
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558037009800018, Alpha: asymmetric, Beta: 0.01
# #Topics: 3, CV Score: 0.41986292638697503, PV Score: -5.558037019038584, Alpha: asymmetric, Beta: 0.01
# #Topics: 4, CV Score: 0.4165450446379923, PV Score: -5.558037006010844, Alpha: asymmetric, Beta: 0.01
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558036990708919, Alpha: asymmetric, Beta: 0.01
# #Topics: 2, CV Score: 0.3261254061364327, PV Score: -5.558037030322679, Alpha: asymmetric, Beta: 0.31
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037022213481, Alpha: asymmetric, Beta: 0.31
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558037007910529, Alpha: asymmetric, Beta: 0.31
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.55803700967673, Alpha: asymmetric, Beta: 0.31
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558037003946465, Alpha: asymmetric, Beta: 0.61
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558037012367746, Alpha: asymmetric, Beta: 0.61
# #Topics: 4, CV Score: 0.34331269338946674, PV Score: -5.558036997716559, Alpha: asymmetric, Beta: 0.61
# #Topics: 5, CV Score: 0.5182431105313009, PV Score: -5.558036995153467, Alpha: asymmetric, Beta: 0.61
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.5580370107096915, Alpha: asymmetric, Beta: 0.9099999999999999
# #Topics: 3, CV Score: 0.34448896557256486, PV Score: -5.558037008751915, Alpha: asymmetric, Beta: 0.9099999999999999
# #Topics: 4, CV Score: 0.34876280047752867, PV Score: -5.558037032020593, Alpha: asymmetric, Beta: 0.9099999999999999
# #Topics: 5, CV Score: 0.3678511744412175, PV Score: -5.558037013034551, Alpha: asymmetric, Beta: 0.9099999999999999
# #Topics: 2, CV Score: 0.3536084476549796, PV Score: -5.558036998288195, Alpha: asymmetric, Beta: symmetric
# #Topics: 3, CV Score: 0.35018841605293183, PV Score: -5.558036994311771, Alpha: asymmetric, Beta: symmetric
# #Topics: 4, CV Score: 0.3879738755865584, PV Score: -5.5580370020758245, Alpha: asymmetric, Beta: symmetric
# #Topics: 5, CV Score: 0.5435572102468758, PV Score: -5.558037018200905, Alpha: asymmetric, Beta: symmetric
# 2023-04-02 16:41:12.600514

# %%
hyperparameter_df = pd.DataFrame(
    {'num_topics': model_topics, 
     'coherence_score': coherence_values, 
     'perplexity_values': perplexity_values,
     'alpha': alpha_result, 
     'beta': beta_result})
hyperparameter_df
# Out:
#      num_topics  coherence_score  perplexity_values       alpha       beta
# 0             2         0.326125          -5.558037        0.01       0.01
# 1             3         0.419863          -5.558037        0.01       0.01
# 2             4         0.416545          -5.558037        0.01       0.01
# 3             5         0.543557          -5.558037        0.01       0.01
# 4             2         0.326125          -5.558037        0.01       0.31
# ..          ...              ...                ...         ...        ...
# 115           5         0.367851          -5.558037  asymmetric       0.91
# 116           2         0.353608          -5.558037  asymmetric  symmetric
# 117           3         0.350188          -5.558037  asymmetric  symmetric
# 118           4         0.387974          -5.558037  asymmetric  symmetric
# 119           5         0.543557          -5.558037  asymmetric  symmetric
#
# [120 rows x 5 columns]

# %%
hyperparameter_df.to_csv("hyperparameter_results.csv")

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(10,3, figsize = (15,40))
x=0
y=0

for model in hyperparameter_df.groupby(['alpha', 'beta']):
    ax[x,y].plot(model[1]['num_topics'], model[1]['coherence_score'])
    ax[x,y].title.set_text("Alpha: " + str(model[0][0]) + ", Beta: " + str(model[0][1]))
    y = y + 1
    if(y == 3):
        y = 0
        x = x + 1
# ax.set_xlabel('num_topics')
# ax.set_ylabel('coherence_score')

# %%
topic_5 = hyperparameter_df[hyperparameter_df["num_topics"] == 5]
topic_5.sort_values(by='coherence_score', ascending=False, inplace=True)
topic_5.head()
# Out:
# C:\Users\genev\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      num_topics  coherence_score  perplexity_values       alpha       beta
# 3             5         0.543557          -5.558037        0.01       0.01
# 39            5         0.543557          -5.558037        0.31  symmetric
# 103           5         0.543557          -5.558037  asymmetric       0.01
# 99            5         0.543557          -5.558037   symmetric  symmetric
# 83            5         0.543557          -5.558037   symmetric       0.01

# %% [markdown]
# ## Final Model
#
# After hyperparameter tuning, we chose the model with the highest coherance_score at 3 topics and decided to use the model with the following parameters:
# - num_topics = 5
# - alpha = 0.01
# - beta = 0.01
#
# which has a coherence score of 0.54 and perplexity value of -5.56.

# %%
k = 5
a = 0.01
b = '0.01'

final_lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                             id2word=id2word,
                                             num_topics=k,
                                             random_state=42,
                                             chunksize=100,
                                             passes=10,
                                             alpha=a,
                                             eta=b)

# %%
pyLDAvis.enable_notebook()
visual= gensimvis.prepare(final_lda_model, corpus, id2word)
#Save the output to the html file
pyLDAvis.save_html(visual, "final_5topic_viz.html")
# Out:
# C:\Users\genev\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)

# %%
visual
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.128209 -0.307555       1        1  28.889892
# 0      0.171603 -0.060917       2        1  22.362101
# 1     -0.152592  0.076945       3        1  19.520363
# 3     -0.347272 -0.006039       4        1  16.440123
# 2      0.200053  0.297565       5        1  12.787521, topic_info=             Term         Freq        Total Category  logprob  loglift
# 4099        dream  4835.000000  4835.000000  Default  30.0000  30.0000
# 318         child  2678.000000  2678.000000  Default  29.0000  29.0000
# 8824        woman  3254.000000  3254.000000  Default  28.0000  28.0000
# 503       country  1831.000000  1831.000000  Default  27.0000  27.0000
# 7592       sexual  2167.000000  2167.000000  Default  26.0000  26.0000
# ...           ...          ...          ...      ...      ...      ...
# 1350         love   414.543203  1302.585915   Topic5  -4.0860   0.9118
# 1619   phenomenon   277.098590  1007.780643   Topic5  -4.4889   0.7656
# 736     endeavour   169.298188   313.424757   Topic5  -4.9816   1.4408
# 7930     stimulus   163.643049   361.671625   Topic5  -5.0155   1.2637
# 1620  philosopher   163.135092   523.661904   Topic5  -5.0186   0.8904
#
# [338 rows x 6 columns], token_table=       Topic      Freq         Term
# term
# 2487       5  0.998198     accuracy
# 2506       1  0.123752     activity
# 2506       2  0.875933     activity
# 2506       4  0.001934     activity
# 73         1  0.995775    affection
# ...      ...       ...          ...
# 2425       1  0.411979        young
# 2425       3  0.584482        young
# 2425       4  0.002029        young
# 16992      2  0.999166  zarathustra
# 16992      3  0.000825  zarathustra
#
# [558 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 1, 2, 4, 3])

# %%
# Save model
lda_sav=final_lda_model

lda_sav.save("finalmodel_5Topics")

# %%
#Code to save the document topic probabilities (theta)
vec=lda_sav[corpus]
pd.DataFrame(vec).to_csv("finaldoc_topic_mixture.csv")

# %%
# Write code here to save top 10 words for each topic (beta)
top_words_per_topic = []
for t in range(lda_sav.num_topics):
    top_words_per_topic.extend([(t, ) + x for x in lda_sav.show_topic(t, topn = 10)])

pd.DataFrame(top_words_per_topic, columns=['Topic', 'Word', 'P']).to_csv("finaltop_words.csv")

# %%
id2word.save(("finalmodel_Dictionary"))
